# %%
from IPython.display import Image
Image('./figs/euclidean_clustering_map.png')

# %% [markdown]
# ## Conclusion
# TODO: find the time for each headline and add time series analysis to find out the time line(s)
